# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("files/AreaPriceData.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df.area,df.price,marker='*',color='blue')
plt.plot(df.area,reg.predict(df[['area']]),color='red')

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['area']] , df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# C:\Users\Parth Hanchate\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
d=pd.read_csv('files/Areas.csv')
d
# Out:
#    area
# 0  1000
# 1  1500
# 2  2300
# 3  3540
# 4  4120
# 5  4560

# %%
reg.predict(d)
# Out:
# array([316404.10958904, 384297.94520548, 492928.08219178, 661304.79452055,
#        740061.64383562, 799808.21917808])

# %%
p=reg.predict(d)
d['price']=p
d.to_csv('files/OutputAreaPrice.csv')
d
# Out:
#    area          price
# 0  1000  316404.109589
# 1  1500  384297.945205
# 2  2300  492928.082192
# 3  3540  661304.794521
# 4  4120  740061.643836
# 5  4560  799808.219178
